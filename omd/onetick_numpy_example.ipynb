# %%
import NumPy_OneTickQuery as otq
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Choose the style of plots
plt.style.use('ggplot')

# %%
# Call the query
result = otq.run_query(["-otq_file C:/OMD/client_data/otqs/vwap.otq -otq_params BucketIntSec=600"])

# %%
# Extract values from numpy array
vwap = result[0][1][1][1]
volume = result[0][1][2][1]
ts = result[0][1][0][1]

# %%
# Plot line on one graph
plt.plot(ts,vwap)

# %% [markdown]
# One can use pandas Series to extract just one set of values

# %%
ser1 = pd.Series(result[0][1][1][1], index=result[0][1][0][1])
ser1.plot()

# %% [markdown]
# One can use pandas DataFrame

# %%
# Put output of the query into the pandas Data Frame
df = pd.DataFrame({'vwap':result[0][1][1][1], 'avg_price':result[0][1][3][1], 
                   'ann_vol':result[0][1][4][1], 'volume':result[0][1][2][1]}, 
                  index=result[0][1][0][1])
df
# Out:
#                       ann_vol  avg_price  volume       vwap
# 2005-01-03 14:40:00  0.158988  99.005157  441400  99.000794
# 2005-01-03 14:50:00  0.206131  98.931082  160900  98.928116
# 2005-01-03 15:00:00  0.275359  98.860117  157100  98.859682
# 2005-01-03 15:10:00  0.292996  98.694530  179500  98.688948
# 2005-01-03 15:20:00  0.271246  98.673241  164800  98.678647
# 2005-01-03 15:30:00  0.237451  98.494017  155100  98.497643
# 2005-01-03 15:40:00  0.289748  98.377307  154200  98.375525
# 2005-01-03 15:50:00  0.161187  98.278797  110800  98.284389
# 2005-01-03 16:00:00  0.119744  98.318697  126700  98.326862
# 2005-01-03 16:10:00  0.268407  98.152248  166000  98.141547
# 2005-01-03 16:20:00  0.118412  98.165641   88900  98.159596
# 2005-01-03 16:30:00  0.100898  98.226407  130700  98.222041
# 2005-01-03 16:40:00  0.176653  98.315767  100200  98.302862
# 2005-01-03 16:50:00  0.084881  98.385310   78300  98.387328
# 2005-01-03 17:00:00  0.141778  98.309041   81100  98.294556
# 2005-01-03 17:10:00  0.208762  98.153561   85100  98.184407
# 2005-01-03 17:20:00  0.287808  98.058728  113200  98.046555
# 2005-01-03 17:30:00  0.082197  97.936677   84700  97.929713
# 2005-01-03 17:40:00  0.047961  97.977213   55300  97.980333
# 2005-01-03 17:50:00  0.164847  98.042088   83900  98.031837
# 2005-01-03 18:00:00  0.153333  98.098420   76800  98.063828
# 2005-01-03 18:10:00  0.199339  98.045101   48100  98.043417
# 2005-01-03 18:20:00  0.070640  98.076458   54500  98.078573
# 2005-01-03 18:30:00  0.377807  97.887428  105000  97.884633
# 2005-01-03 18:40:00  0.116341  97.890787   54100  97.896568
# 2005-01-03 18:50:00  0.122184  97.937071   59400  97.935343
# 2005-01-03 19:00:00  0.091875  97.848423  128800  97.845992
# 2005-01-03 19:10:00  0.156350  97.920596   55700  97.926259
# 2005-01-03 19:20:00  0.143217  97.947495   66800  97.944995
# 2005-01-03 19:30:00  0.097417  97.934791   38300  97.931407
# 2005-01-03 19:40:00  0.232155  98.034944   50700  98.042681
# 2005-01-03 19:50:00  0.139195  98.016766   46200  98.017280
# 2005-01-03 20:00:00  0.303920  97.974636   77900  97.965665
# 2005-01-03 20:10:00  0.104320  97.884800  113700  97.880405
# 2005-01-03 20:20:00  0.279526  97.798040  133300  97.803992
# 2005-01-03 20:30:00  0.169066  97.645038  155800  97.649954
# 2005-01-03 20:40:00  0.217192  97.565300  234300  97.554302
# 2005-01-03 20:50:00  0.370416  97.520676  300400  97.494839
# 2005-01-03 21:00:00  0.290139  97.366253  344600  97.422979

# %%
df.plot(subplots=True, figsize=(12,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A96E710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA173C8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA60898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AA9C9E8>], dtype=object)

# %%
df.vwap.plot()
