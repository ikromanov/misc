# %%
import pandas as pd
import numpy as np

# %%
holdings = pd.read_csv('../input/ivv_holdings.csv')

# %%
holdings.head()
# Out:
#   Ticker                  Name                  Sector Asset Class  \
# 0   AAPL             APPLE INC  Information Technology      Equity
# 1   MSFT        MICROSOFT CORP  Information Technology      Equity
# 2   AMZN        AMAZON COM INC  Consumer Discretionary      Equity
# 3     FB  FACEBOOK CLASS A INC           Communication      Equity
# 4  GOOGL  ALPHABET INC CLASS A           Communication      Equity
#
#         Market Value  Weight (%)     Notional Value          Shares  \
# 0  14,858,321,760.24        5.80  14,858,321,760.24  123,839,988.00
# 1  13,616,583,453.78        5.32  13,616,583,453.78   58,586,109.00
# 2  10,104,099,800.88        3.95  10,104,099,800.88    3,304,542.00
# 3   4,934,292,564.90        1.93   4,934,292,564.90   18,627,001.00
# 4   4,743,438,993.54        1.85   4,743,438,993.54    2,329,566.00
#
#        CUSIP          ISIN    SEDOL     Price       Location Exchange  \
# 0   37833100  US0378331005  2046251    119.98  United States   NASDAQ
# ...

# %%
print(holdings.Sector.unique())
# Out:
# ['Information Technology' 'Consumer Discretionary' 'Communication'
#  'Financials' 'Health Care' 'Consumer Staples' 'Energy' 'Industrials'
#  'Utilities' 'Materials' 'Real Estate' 'Cash and/or Derivatives' nan]

# %%
nan = holdings[holdings.Sector == 'nan']

# %%
nan
# Out:
# Empty DataFrame
# Columns: [Ticker, Name, Sector, Asset Class, Market Value, Weight (%), Notional Value, Shares, CUSIP, ISIN, SEDOL, Price, Location, Exchange, Currency, FX Rate, Market Currency, Accrual Date]
# Index: []

# %%
it = holdings[holdings.Sector == 'Information Technology']
finance = holdings[holdings.Sector == 'Financials']

# %%
len(finance)
# Out:
# 65

# %%
finance[['Ticker','Name','Weight (%)']]
# Out:
#     Ticker                               Name  Weight (%)
# 6     BRKB     BERKSHIRE HATHAWAY INC CLASS B        1.56
# 8      JPM                JPMORGAN CHASE & CO        1.43
# 17     BAC               BANK OF AMERICA CORP        0.86
# 39     WFC                        WELLS FARGO        0.50
# 45       C                      CITIGROUP INC        0.47
# 59      MS                     MORGAN STANLEY        0.38
# 63      GS            GOLDMAN SACHS GROUP INC        0.36
# 69     BLK                      BLACKROCK INC        0.31
# 73    SCHW                CHARLES SCHWAB CORP        0.29
# 74     AXP                   AMERICAN EXPRESS        0.29
# 87    SPGI                     S&P GLOBAL INC        0.25
# 92     TFC              TRUIST FINANCIAL CORP        0.24
# 95      CB                          CHUBB LTD        0.24
# 97     PNC   PNC FINANCIAL SERVICES GROUP INC        0.23
# 100    CME              CME GROUP INC CLASS A        0.22
# ...
