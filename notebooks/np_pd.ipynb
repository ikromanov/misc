# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
my_list1 = [1, 2, 3, 4]

# %%
my_array1 = np.array(my_list1)

# %%
my_array1
# Out:
# array([1, 2, 3, 4])

# %%
my_array1.shape
# Out:
# (4,)

# %%
arr1 = np.array([[1,2,3,4],[8,9,10,11]])

# %%
arr1*arr1
# Out:
# array([[  1,   4,   9,  16],
#        [ 64,  81, 100, 121]])

# %%
arr = np.arange(0,11)

# %%
# Important: if you modify the slice of array the original array is affected.
arr_slice = arr[0:5]
arr_slice[:] = 100
arr
# Out:
# array([100, 100, 100, 100, 100,   5,   6,   7,   8,   9,  10])

# %%
# To make a copy use explicit method
arr_copy = arr.copy()[:5]
arr_copy[:] = 123
arr
# Out:
# array([100, 100, 100, 100, 100,   5,   6,   7,   8,   9,  10])

# %%
arr_2d = np.array(([5,10,15],[20,25,30],[35,40,45]))

arr_2d[0], arr_2d[1][0]
# Out:
# (array([ 5, 10, 15]), 20)

# %%
arr_2d[:2,1:]
# Out:
# array([[10, 15],
#        [25, 30]])

# %%
points = np.arange(-5,5,0.01)
dx,dy = np.meshgrid(points,points)

# %%
z = (np.sin(dx) + np.sin(dy))

# %%
plt.imshow(z)

# %%
plt.imshow(z)
plt.colorbar()

plt.title('Plot for six(x) + sin(y)')
